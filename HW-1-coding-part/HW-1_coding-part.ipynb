# %% [markdown]
# ### TYPE YOUR NAME HERE: Gabriel Ferraz

# %% [markdown]
# ## ISM 5644 - Programming for Analytics
#
# ## Assignment 1 - Coding Section

# %% [markdown]
# ### Important: Assignments are to be completed and submitted *individually* - i.e., you are <u>not</u> allowed to work in groups.
# ### Task:
# The code cells in this notebook have been left blank. Your task is to complete these cells and provide the execution results. The corresponding question text for each code cell is provided above the cell.

# %% [markdown]
# ### Questions:

# %% [markdown]
# #### 1. Suppose that you have a string ab_string = ‘ababababab’. Write an expression to remove all the ‘b’s and create a string, a_string = ‘aaaaa’.

# %%
ab_string = 'ababababab'
notb_string = ''
b_string = ''

for i in ab_string:
    if i == 'b':
        b_string += i
    
    else:
        notb_string += i
notb_string = a_string

print(a_string)
# Out:
# aaaaa

# %% [markdown]
# #### 2. Consider two strings: s1 and s2 that are can be of arbitrary length. Create a new string consisting of the first character of s1 followed by the first character of s2, followed by the second character of s1, followed by the second character of s2, and so on (in other words the new string should consist of alternating characters of s1 and s2). If s1 and s2 are <u>not</u> the same length, then the program should add the remaining characters of the longer string to the end of the output. For example, if s1contained "hey" and s2 contained "world", then the new string should contain "hweoyrld".

# %%
s2 = 'world'
s1 = 'greeting'

new_string = ''
remaining_string = ''

if len(s1) < len(s2):
    for i in range(len(s1)):
        new_string += s1[i]
        new_string += s2[i]
    new_string += s2[i+1:]
else: 
    for i in range(len(s2)):
        new_string += s1[i]
        new_string += s2[i]
    new_string += s1[i+1:]
         
    
print(new_string)
# Out:
# gwroereltding

# %% [markdown]
# #### 3. Write a program using a for loop that takes a sentence S as an argument and returns the words in S in reversed order. For example, if S = "I like programming for analytics", then it should return "analytics for programming like I".

# %%
S = 'I like programming for analytics'
S_split = S.split(' ')
reverse_S_split = S_split[::-1]
output = ''
for i in reverse_S_split:
    output = output + ' ' + i
    


#for i in S:
 #   S_split = S.split(' ')
  #  reverse_S_split = S_split[::-1]
   # reverse_S = ' '.join(reverse_S_split)
    
print(output)
# Out:
#  analytics for programming like I

# %% [markdown]
# #### 4. Assume that there exists a string called my_str. Write a program to check if there are duplicate characters (i.e., if any character appears more than once) in my_str. Print out the characters that are duplicate, along with their respective duplicate counts. In your output, make sure that each duplicate character (if any) is printed out only a single time.

# %%
phrase = 'dandelion'
duplicate = []

#duplicate characters in dandelion?

#letter in dandelion appears more than once

#if a letter, or i in dandelion has count > 1

#then i += 1

#and

#then print(i)

for i in phrase:
    if phrase.count(i) > 1:
        if i not in duplicate:
            cnt = phrase.count(i)
            print('The letter', i ,'appears', cnt, 'times')
            duplicate.append(i)
# Out:
# The letter d appears 2 times
# The letter n appears 2 times

# %% [markdown]
# #### 5. Write a program to prompt the user for a string date input. The user can write the date as m/d/y or m-d-y. They also have the flexibility to enter the input using single or double digit  for date and month (9 vs. 09) and two or four digits for year (19 vs. 2019). From any given input under these possibilities, return the value in the following format: dd-mm-yy (always two digits for date, month, and year).

# %%
date = str(input('Give me a date in m/d/y or m-d-y:'))

if '/' in date:
    datesplitslash = date.split('/')
else:
    datesplitslash = date.split('-')
    
day = datesplitslash[1]
month = datesplitslash[0]
year = datesplitslash[2]

if len(day) != 2:
    day = '0' + day

if len(month) != 2:
    month = '0' + month

if len(year) != 2:
    year = year[2:]

output = day + '-' + month + '-' + year
print(output)
# Out:
# Give me a date in m/d/y or m-d-y: 10-24-2022
# 24-10-22

# %% [markdown]
# #### 6. Given a list of numbers, create a new list of numbers such that the first and last numbers are added and stored as the first number, the second and second-to-last numbers are stored as the second number, and so on. Note that you need to check for even and odd length of lists. In case of an odd number of integers, add the central integer in the original list to the end of the new list.

# %%
alist = [11,23,35,57,79,101,235]
new_list = []
num_of_pairs = len(alist) // 2

for i in range(num_of_pairs):
    new_num = alist[i] + alist[-1 + -i]
    new_list.append(new_num)
if len(alist) % 2 != 0:
     middle_i = len(alist) // 2
     centralint = alist[middle_i]
     new_list.append(centralint)
  


print(new_list)
# Out:
# [246, 124, 114, 57]

# %% [markdown]
# #### 7. Write a program that prompts the user for a number that is more than two digits (e.g., 123, 1234, 12345, etc.). The program should divide this input into three parts (according to the rules below) and then print them as a single string joined by hyphens (-).
#
# - If the number of digits is divisible by 3, then each part should have equal number of digits. For instance, if the input is "123", then the output should be: “1-2-3”.
# - If the number of digits is not divisible by 3, then the first two parts should have equal number of digits whereas the last part should be longer than the first two. For instance, if the input is "54321", then the result should be "5-4-321". If the input is "1234567", then the output should be "12-34-567".

# %%
num = int(input('Give a number more than two digits'))
str_num = str(num)

while num >= 10:
    if len(str_num) % 3 == 0:
        print(num)
# Out:
# Give a number more than two digits 90
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[204], line 4
#       1 num = int(input('Give a number more than two digits'))
#       2 str_num = str(num)
# ----> 4 while num >= 10:
#       5     if len(str_num) % 3 == 0:
#       6         print(num)
#
# KeyboardInterrupt:

# %% [markdown]
# #### 8. Write a program that finds all the perfect numbers between 1 and *n*, where *n* is a user input collected by the program.
# #### *Definition*: A perfect number is a positive integer that is equal to the sum of its positive factors, excluding the number itself. For instance, the number 6 has the factors: 1, 2, and 3. The sum of the factors are: 1+2+3 = 6, which is the number itself. Accordingly, the number 6 is a perfect number.
# Hint: You can use / expand the code from an earlier lab question (i.e., finding all the factors of a number) to answer this question.

# %%
n = int(input('Give me a number:'))

for num in range(1,n+1):
    total = 0
    for i in range(1,num):
        if num % i == 0:
            total += i
    if total == num:
        print(num)
# Out:
# Give me a number: 32
# 6
# 28

# %% [markdown]
# #### 9. Assume that we are given a list variable, with each element in the list is numeric (int or float). Check if the numbers in this list is in ascending order (that is, if each element of the list is greater than or equal to the previous element in the list). Print out your finding.
# Hint: You can use a *for* loop to answer this question. To access a particular element in a list, use its index in brackets. For example, my_list[2] returns the 3rd element in my_list. A "break" statement can also be helpful for stopping the execution of the loop early (for instance when the program finds that the list is not in ascending order).

# %%
blist = [1,5,7,9,52,78,101]
ascending = True

for i in range(1,len(blist)):
    if blist[i] < blist[i + -1]:
        ascending = False
        break

if ascending:
    print('yes')
else:
    print('no')
# Out:
# yes

# %% [markdown]
# #### 10. Write a program that prompts for an integer - let's call it X - and then finds the consecutive sums of all integers between 1 and X. For example, suppose that 5 is entered, i.e., X = 5. Then, you will need to obtain five sums of consecutive numbers as:
# 1 = 1 <br>
# 1+2 = 3 <br>
# 1+2+3 = 6 <br>
# 1+2+3+4 = 10 <br>
# 1+2+3+4+5 = 15 <br>
# #### Ideally, the output of the program should be as it is shown above. If you cannot get the left hand sides printed out (i.e., individual summation elements and '+' signs), then it is OK to only print out the total sums (1, 3, 6, 10, and 15 for the example above) on separate lines.

# %%
X = int(input('Give me an integer:'))
begin = 0
add = 0

for num in range(1,X+1):
    begin += 1
    add += begin
    print(add)
# Out:
# Give me an integer: 12
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
