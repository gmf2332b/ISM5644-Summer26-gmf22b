# %% [markdown]
# ### TYPE YOUR NAME HERE: Gabriel Ferraz

# %% [markdown]
# # ISM 5644 - Programming for Analytics
#
# ## Lab Exercise: Dictionary & String Data Structures

# %% [markdown]
# ### Overview:
# This lab covers operations related to dictionaries and strings.

# %% [markdown]
# ### Task:
# The code cells in this notebook have been left blank. Your task is to complete these cells and provide the execution results. The corresponding question text for each code cell is provided above the cell. Once you have completed the lab, you should publish your notebook code (the code in the .ipynb file) as a "Secret Gist" on your GitHub repository and obtain the Gist ID.
# ### Submission Format:
# There are two deliverables of this lab: 1) the Gist ID and 2) the completed .ipynb file. Both of these should be submitted on Canvas using the corresponding lab submission link by the due date indicated on Canvas.

# %% [markdown]
# ### Questions:

# %% [markdown]
# #### 1. Assume that there exists two lists in memory that are of the same length. The first list contains user names (e.g., ['Jane','Joe','Sally']) and the second list contains user IDs (e.g., [101,102,103]). Write a program that creates a single dictionary which maps user names to user IDs. In the dictionary, names should be used as keys and IDs should be used as values. The user name list can be of arbitrary length.
# Hint: Use a loop to iterate over the length of lists and obtain values using indices.

# %%
usernames = ['Jane','Joe','Sally']
userid = [101,102,103]

newDict = {usernames[0]:userid[0],usernames[1]:userid[1],usernames[2]:userid[2]}
print(newDict)
# Out:
# {'Jane': 101, 'Joe': 102, 'Sally': 103}

# %% [markdown]
# #### 2. Assume that there exists a dictionary that stores integer values. Write a program that asks the user for an integer input, searches this input in the <u>values</u> of the dictionary, and prints out the input's associated key. If the input is not in the dictionary, the program should print out a <u>not found</u> message.
# Hint: To test the program, you can initialize an arbitrary dictionary such as d = {'a':10,'b':20,'c':30}

# %%
d = {'a':10,'b':20,'c':30}
integer = int(input('write an integer:'))

for key,value in d.items():
    if value == integer:
        print(key)
        break
else:
    print('not found')
# Out:
# write an integer: 20
# b

# %% [markdown]
# #### 3. Write a program to prompt the user for a string date input in the form of mm/dd/yyyy, for example 09/08/2018. Assign this input to a variable called a_date. Next, assign the month value in a_date to a variable named a_month. Then, convert a_month to integer type to check if a_month is a valid entry. The program should print out a warning message, if the month value in a_date is not correct. For instance, 15/08/2018 is not valid input because month value cannot be greater than 12.
# Hint: Consider using the split method.

# %%
a_date = input('Enter a date in the mm/dd/yyyy format:')
date_split = a_date.split('/')
a_month = date_split[0]
int_month = int(a_month)

if int_month < 1:
    print('Warning!')
elif int_month > 12:
    print('Warning!')
# Out:
# Enter a date in the mm/dd/yyyy format: 02/17/1994

# %% [markdown]
# #### 4. Given three String variables that have been given values, firstName, middleName, and lastName, write an expression whose value is the initials of the three names: the first letter of each, joined together. So if firstName, middleName, and lastName, had the values "John", "Fitzgerald", and "Kennedy", the expression's value would be "JFK".

# %%
firstName = 'John'
middleName = 'Fitzgerald'
lastName = 'Kennedy'
initials = firstName[0] + middleName[0] + lastName[0]
print(initials)
# Out:
# JFK

# %% [markdown]
# #### 5. Given a person’s name as a string as: ‘FirstName LastName’, write an expression that prints the FirstName. For example, if the string is ‘Jane Doe’, then it should print ‘Jane’. Note that the length of the first / last name can vary.
# Note: You are <u>only</u> allowed to use the .find() method to answer this question (to find the whitespace). Do not use any other methods.

# %%
firstName_lastName = 'Jonathan Doe'
firstName = firstName_lastName[0:firstName_lastName.find(' ')]
print(firstName)
# Out:
# Jonathan

# %% [markdown]
# #### 6. Write a program that prompts the user for a number input with 10 digits (such as 8005551212). If the input is 10 digits, the program should divide this input into three parts consisting of 3 digits, 3 digits, and 4 digits and print them as a single string joined by hyphens (-). For example, if the input is 8005551212, then the output should be: “800-555-1212”. If the user input is <u>not</u> in 10 digits, it should display a warning message and prompt the user again. The program should run <u>iteratively</u> until a 10 digit input is entered.
# Hint: You can initialize the program with a While loop that will iteratively run until a condition has been met.

# %%
ten_digit = True

while True:
    number = int(input('Give me a 10 digit number:'))
    str_num = str(number)
    hyphen = '-'
    first3 = str_num[0:3]
    second3 = str_num[3:6]
    third4 = str_num[6:]
    phone_number = first3 + hyphen + second3 + hyphen + third4
    
    if len(str_num) != 10:
        ten_digit = False
        print('Warning!')

    else:
        print(phone_number)
        break

# 4340493859
# 434-049-3859
# Out:
# Give me a 10 digit number: 4073341361
# 407-334-1361

# %% [markdown]
# #### 7. Given the strings s1 and s2, which are of the same length, create a new string consisting of alternating characters of s1 and s2 (that is, the first character of s1 followed by the first character of s2, followed by the second character of s1, followed by the second character of s2, and so on. For example, if s1 contained "hello" and s2 contained "world", then the new string should contain "hweolrllod".
# Hint: You can loop over the length of strings and pick up a single character from each string at each iteration.

# %%
s1 = 'hello'
s2 = 'world'

new_string = ' '

for i in range(len(s1)):
    new_string += s1[i]
    new_string += s2[i]

print(new_string)
# Out:
#  hweolrllod

# %% [markdown]
# #### 8. Given a person’s full name as a string, write an expression that prints the the initials of the person -- each character followed by a period. For example, if the string is ‘Jane Doe’, then it should print ‘J.D.’. If the person's name is 'Jane Mary Berry Doe', then it should print 'J.M.B.D.' Note that the middle name is optional; there can be zero or more middle names included in the full name. Also, the length of the first / middle / last names can vary.
# Hint: You can use the .split() method to spearate the individual words in the name string.

# %%
fullname = 'Jane Mary Berry Doe'
name_split = fullname.split(' ')
initials = ''
for i in name_split:
    initials += i[0] + '.'
print(initials)
# Out:
# J.M.B.D.

# %% [markdown]
# #### 9. Convert a string that consists of two words that are both capitalized into a string where only the first letters of the words are capitalized. For example, convert “NEW YORK” to “New York”.
# Note: You are <u>*not*</u> allowed to use the .title() method.

# %%
bothupper = 'NEW YORK'
bothlower = bothupper.lower()
bothlower_split = bothlower.split(' ')
title = []
for i in bothlower_split:
    capital = i.capitalize()
    title.append(capital)
together = ' '.join(title)
print(together)
# Out:
# New York

# %% [markdown]
# #### 10. Write a program that returns True if a given string (user input) includes every letter of the alphabet. If the string does not contain each letter, print which ones are missing. The results should <u>not</u> depend on capitalization.
# Hint: You can use the following code snippet to load the letters in the alphabet into a string called alphabet_str: <br>
# *import string <br>
# alphabet_str = string.ascii_lowercase* <br>
# Next, you can loop over the alphabet letters to check if they are included in the string or not.

# %%
import string
alphabet_str = string.ascii_lowercase
phrase = input('Give me a phrase:').lower()
missing_letters = []

for i in alphabet_str:
    if i not in phrase:
        missing_letters.append(i)
if len(missing_letters) == 0:
    print(True)
else:
    missing = ', '.join(missing_letters)
    print(False, 'These are the missing letters: {}'.format(missing))
# Out:
# Give me a phrase: Florida State University
# False These are the missing letters: b, c, g, h, j, k, m, p, q, w, x, z
